# %% [markdown]
# <h2>Peer-graded Assignment:</h2> Capstone Project Notebook
# <h1>Create a new repository on your Github account and name it Coursera_Capstone. If you don't have a Github account yet, please create one and follow the instructions here: https://services.github.com/on-demand/intro-to-github/create-github-account.</h1>
#
# Now, start a Jupyter Notebook using any platform that you are comfortable with and do the following:
#
# 1) Write some markdown to explain that this notebook will be mainly used for the capstone project.
#
# 2) Import the pandas library as pd.

# %%
import pandas as pd

# %% [markdown]
# 3) Import the Numpy library as np.

# %%
import numpy as np
